# %%
import pandas as pd

# %%
df = pd.read_csv("fifa_world_cup_2026_player_performance-selected-columns.csv")
df
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot
# ...

# %%
df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot
# 0  Goalkeeper        195         75           Left
# 1  Midfielder        178         75          Right
# 2  Midfielder        177         72           Left
# 3     Forward        182         74          Right
# 4    Defender        191         81           Left

# %%
df.tail()
# Out:
#       player_id       player_name  age nationality  team  jersey_number  \
# 54595    P00996       Amir Younis   28       Iraqi  Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi  Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi  Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi  Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi  Iraq              1
#
#          position  height_cm  weight_kg preferred_foot
# 54595    Defender        177         73          Right
# 54596  Midfielder        176         72          Right
# 54597  Midfielder        173         77           Left
# 54598  Goalkeeper        190         81          Right
# 54599  Goalkeeper        187         73          Right

# %%
df.shape
# Out:
# (54600, 10)

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'team',
#        'jersey_number', 'position', 'height_cm', 'weight_kg',
#        'preferred_foot'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 54600 entries, 0 to 54599
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_id       54600 non-null  str
#  1   player_name     54600 non-null  str
#  2   age             54600 non-null  int64
#  3   nationality     54600 non-null  str
#  4   team            54600 non-null  str
#  5   jersey_number   54600 non-null  int64
#  6   position        54600 non-null  str
#  7   height_cm       54600 non-null  int64
#  8   weight_kg       54600 non-null  int64
#  9   preferred_foot  54600 non-null  str
# dtypes: int64(4), str(6)
# memory usage: 4.2 MB

# %%
df.dtypes
# Out:
# player_id           str
# player_name         str
# age               int64
# nationality         str
# team                str
# jersey_number     int64
# position            str
# height_cm         int64
# weight_kg         int64
# preferred_foot      str
# dtype: object

# %%
df.isnull().sum()
# Out:
# player_id         0
# player_name       0
# age               0
# nationality       0
# team              0
# jersey_number     0
# position          0
# height_cm         0
# weight_kg         0
# preferred_foot    0
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#      player_id         player_name  age nationality     team  jersey_number  \
# 0       P00055          Rodri Fati   26     Spanish    Spain              3
# 1       P00070     Ansu Le Normand   19     Spanish    Spain             18
# 2       P00066          Gavi Ramos   18     Spanish    Spain             14
# 3       P00073       Pedro Cubarsi   20     Spanish    Spain             21
# 4       P00059    Alvaro Oyarzabal   23     Spanish    Spain              7
# ...        ...                 ...  ...         ...      ...            ...
# 5143    P00324      Philipp Friedl   24    Austrian  Austria             12
# 5144    P00320  Stefan Hinteregger   24    Austrian  Austria              8
# 5145    P00326       Marcel Dembir   22    Austrian  Austria             14
# 5146    P00313      David Sabitzer   31    Austrian  Austria              1
# 5147    P00314       Marcel Lainer   21    Austrian  Austria              2
#
#         position  height_cm  weight_kg preferred_foot
# ...

# %%
cleaned_df = pd.read_csv("cleaned_fifa_dataset.csv")
cleaned_df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot
# 0  Goalkeeper        195         75           Left
# 1  Midfielder        178         75          Right
# 2  Midfielder        177         72           Left
# 3     Forward        182         74          Right
# 4    Defender        191         81           Left

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Missing Values:
# player_id         0
# player_name       0
# age               0
# nationality       0
# team              0
# jersey_number     0
# position          0
# height_cm         0
# weight_kg         0
# preferred_foot    0
# dtype: int64
#
# Duplicate Rows: 0

# %%
df.describe()
# Out:
#                age  jersey_number    height_cm    weight_kg
# count  1248.000000    1248.000000  1248.000000  1248.000000
# mean     26.303686      13.500000   181.633013    75.745192
# std       4.071130       7.503007     6.266593     3.951081
# min      17.000000       1.000000   163.000000    65.000000
# 25%      23.750000       7.000000   177.000000    73.000000
# 50%      26.000000      13.500000   182.000000    76.000000
# 75%      29.000000      20.000000   186.000000    78.000000
# max      39.000000      26.000000   200.000000    87.000000

# %%
df.nunique()
# Out:
# player_id         1248
# player_name       1245
# age                 23
# nationality         48
# team                48
# jersey_number       26
# position             4
# height_cm           37
# weight_kg           22
# preferred_foot       2
# dtype: int64

# %%
df.to_csv("cleaned_fifa_dataset.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
cleaned_df = pd.read_csv("cleaned_fifa_dataset.csv")
cleaned_df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot
# 0  Goalkeeper        195         75           Left
# 1  Midfielder        178         75          Right
# 2  Midfielder        177         72           Left
# 3     Forward        182         74          Right
# 4    Defender        191         81           Left

# %%
cleaned_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1248 entries, 0 to 1247
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_id       1248 non-null   str
#  1   player_name     1248 non-null   str
#  2   age             1248 non-null   int64
#  3   nationality     1248 non-null   str
#  4   team            1248 non-null   str
#  5   jersey_number   1248 non-null   int64
#  6   position        1248 non-null   str
#  7   height_cm       1248 non-null   int64
#  8   weight_kg       1248 non-null   int64
#  9   preferred_foot  1248 non-null   str
# dtypes: int64(4), str(6)
# memory usage: 97.6 KB
